# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

! mkdir "Satellite Imagery of Central Java"
! mkdir "Settlement Mapping of Central Java"

# %%
# Downloading sample: kab-tegal.png
os.system("gdown https://drive.google.com/uc?id=1_fbEtBdN-Ey4LUXRPveq63FhKKGebuub")
! mv "kab-tegal.png" "Satellite Imagery of Central Java"

os.system("gdown https://drive.google.com/uc?id=1G8tdpsgMH8DcAvFao42Vo701IimjZ5Hj")
! mv "kab-tegal.png" "Settlement Mapping of Central Java"

# %%
for name in ["tegal"]: # Specify the names of kab/kota to count the pixels.
  # folder = "Satellite Imagery of Central Java"
  # folder = "Satellite Imagery of East Java"
  folder = "Settlement Mapping of Central Java"
  # folder = "Settlement Mapping of East Java"

  filename = f"kab-{name.lower()}.png"
  
  img = cv2.imread(f"{folder}/{filename}")
  grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  grayImg = (grayImg > 0).astype('uint8')

  pixels = np.sum(grayImg.flatten())
  print(f"{pixels}")

  # plt.figure(figsize=(15,15))
  # plt.axis("off")
  # plt.imshow(grayImg, cmap="gray")
  # plt.show()
